# %%
from IPython.display import Image
# %matplotlib inline

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('src'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from predict import load_predictor, random_file, download
from visualise import draw
from uuid import uuid4
import urllib3

# %%
owner_id = -70232735
rf = random_file(owner_id)
pred = load_predictor(owner_id)

# %% [markdown]
# ## Pictures from the dataset

# %%
# to get random picture
rf()
# Out:
# 'data/images_-70232735/422998364_1467658893_XHMh9hWvWR4.jpg'

# %%
f = 'data/images_-70232735/390545639_1448456766_LYIo1P106sI.jpg'
print(f)
draw(pred(f), f)
# Out:
# data/images_-70232735/390545639_1448456766_LYIo1P106sI.jpg

# %%
f = 'data/images_-70232735/377833373_1440086185_37JfC9mGOOM.jpg'
print(f)
draw(pred(f), f)
# Out:
# data/images_-70232735/377833373_1440086185_37JfC9mGOOM.jpg

# %%
f = 'data/images_-70232735/345523997_1416606367_cIel7Kx2sss.jpg'
print(f)
draw(pred(f), f)
# Out:
# data/images_-70232735/345523997_1416606367_cIel7Kx2sss.jpg

# %%
f = 'data/images_-70232735/456241636_1483703928_VCq1kQ6cYnQ.jpg'
print(f)
draw(pred(f), f)
# Out:
# data/images_-70232735/456241636_1483703928_VCq1kQ6cYnQ.jpg

# %% [markdown]
# ## Other pictures
#
# Try to seach similar pictures for the target tht doesn't present in the dataset

# %%
f = download('https://pp.userapi.com/c306809/v306809043/9651/LMuGUlYSURk.jpg')
print(f)
draw(pred(f), f)
# Out:
# /tmp/images/12c1f10d-d604-460e-b051-9e0ce785fbb8

# %%
f = download('https://pp.userapi.com/c624726/v624726018/1733/y4kuQ4AqKpA.jpg')
print(f)
draw(pred(f), f)
# Out:
# /tmp/images/b40282b3-9121-4e1a-aebf-cbed2b19d09e

# %% [markdown]
# ## Another dataset

# %%
owner_id = -29937425
rf = random_file(owner_id)
pred = load_predictor(owner_id)

# %%
f = download('https://pp.userapi.com/c306809/v306809043/9651/LMuGUlYSURk.jpg')
print(f)
draw(pred(f), f)
# Out:
# /tmp/images/80956c1b-cbd5-4404-b8bc-372c353f9f19
